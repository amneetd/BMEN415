# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.12.0-cp38-cp38-macosx_10_15_x86_64.whl (230.1 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1; platform_machine != "arm64" or platform_system != "Darwin"
#   Using cached tensorflow_io_gcs_filesystem-0.32.0-cp38-cp38-macosx_10_14_x86_64.whl (1.7 MB)
# Collecting keras<2.13,>=2.12.0
#   Using cached keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Processing /Users/alyssajames/Library/Caches/pip/wheels/45/83/1e/3db22c5e1941c10e41c4f5cdf829b0a358146d4d0733d4a105/jax-0.4.8-py3-none-any.whl
# Requirement already satisfied: setuptools in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (50.3.1.post20201107)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: h5py>=2.9.0 in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.11.2)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-23.3.3-py2.py3-none-any.whl (26 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Using cached protobuf-4.22.1-py3-none-any.whl (172 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: six>=1.12.0 in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.7.4.3)
# Collecting numpy<1.24,>=1.22
#   Using cached numpy-1.23.5-cp38-cp38-macosx_10_9_x86_64.whl (18.1 MB)
# Collecting tensorboard<2.13,>=2.12
#   Using cached tensorboard-2.12.1-py3-none-any.whl (5.6 MB)
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Using cached tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-16.0.0-py2.py3-none-macosx_10_9_x86_64.whl (26.7 MB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: packaging in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (20.4)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.53.0.tar.gz (22.4 MB)
# Collecting ml-dtypes>=0.0.3
#   Using cached ml_dtypes-0.0.4.tar.gz (684 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Collecting scipy>=1.7
#   Using cached scipy-1.10.1-cp38-cp38-macosx_10_9_x86_64.whl (35.0 MB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow) (0.35.1)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.17.1-py2.py3-none-any.whl (178 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.24.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.0-py3-none-macosx_10_9_x86_64.whl (4.8 MB)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.1)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.3-py3-none-any.whl (93 kB)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from packaging->tensorflow) (2.4.7)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2020.6.20)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4; python_version < "3.10"
#   Using cached importlib_metadata-6.1.0-py3-none-any.whl (21 kB)
# Collecting pyasn1>=0.1.3
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (3.4.0)
# Building wheels for collected packages: grpcio, ml-dtypes
#   Building wheel for grpcio (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/alyssajames/opt/anaconda3/bin/python -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-install-olv8jqwe/grpcio/setup.py'"'"'; __file__='"'"'/private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-install-olv8jqwe/grpcio/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-wheel-nbrqbk_u
#        cwd: /private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-install-olv8jqwe/grpcio/
#   Complete output (697 lines):
#   Found cython-generated files...
#   running bdist_wheel
#   running build
#   running build_py
#   running build_project_metadata
#   creating python_build
#   creating python_build/lib.macosx-10.10-x86_64-3.8
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   copying src/python/grpcio/grpc/_typing.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   copying src/python/grpcio/grpc/_compression.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   copying src/python/grpcio/grpc/_channel.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   copying src/python/grpcio/grpc/_common.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   copying src/python/grpcio/grpc/__init__.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   copying src/python/grpcio/grpc/_utilities.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   copying src/python/grpcio/grpc/_simple_stubs.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   copying src/python/grpcio/grpc/_plugin_wrapping.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   copying src/python/grpcio/grpc/_interceptor.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   copying src/python/grpcio/grpc/_grpcio_metadata.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   copying src/python/grpcio/grpc/_server.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   copying src/python/grpcio/grpc/_runtime_protos.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   copying src/python/grpcio/grpc/_auth.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc/beta
#   copying src/python/grpcio/grpc/beta/_server_adaptations.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/beta
#   copying src/python/grpcio/grpc/beta/interfaces.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/beta
#   copying src/python/grpcio/grpc/beta/_metadata.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/beta
#   copying src/python/grpcio/grpc/beta/__init__.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/beta
#   copying src/python/grpcio/grpc/beta/utilities.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/beta
#   copying src/python/grpcio/grpc/beta/implementations.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/beta
#   copying src/python/grpcio/grpc/beta/_client_adaptations.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/beta
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc/experimental
#   copying src/python/grpcio/grpc/experimental/gevent.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/experimental
#   copying src/python/grpcio/grpc/experimental/__init__.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/experimental
#   copying src/python/grpcio/grpc/experimental/session_cache.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/experimental
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework
#   copying src/python/grpcio/grpc/framework/__init__.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc/aio
#   copying src/python/grpcio/grpc/aio/_base_server.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/aio
#   copying src/python/grpcio/grpc/aio/_metadata.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/aio
#   copying src/python/grpcio/grpc/aio/_typing.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/aio
#   copying src/python/grpcio/grpc/aio/_call.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/aio
#   copying src/python/grpcio/grpc/aio/_channel.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/aio
#   copying src/python/grpcio/grpc/aio/__init__.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/aio
#   copying src/python/grpcio/grpc/aio/_base_channel.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/aio
#   copying src/python/grpcio/grpc/aio/_interceptor.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/aio
#   copying src/python/grpcio/grpc/aio/_server.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/aio
#   copying src/python/grpcio/grpc/aio/_base_call.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/aio
#   copying src/python/grpcio/grpc/aio/_utils.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/aio
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc/_cython
#   copying src/python/grpcio/grpc/_cython/__init__.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/_cython
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc/experimental/aio
#   copying src/python/grpcio/grpc/experimental/aio/__init__.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/experimental/aio
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/callable_util.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/abandonment.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/__init__.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/stream.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/stream_util.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/future.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/foundation
#   copying src/python/grpcio/grpc/framework/foundation/logging_pool.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/foundation
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/common
#   copying src/python/grpcio/grpc/framework/common/style.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/common
#   copying src/python/grpcio/grpc/framework/common/cardinality.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/common
#   copying src/python/grpcio/grpc/framework/common/__init__.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/common
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/interfaces
#   copying src/python/grpcio/grpc/framework/interfaces/__init__.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/interfaces
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/interfaces/face
#   copying src/python/grpcio/grpc/framework/interfaces/face/__init__.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/interfaces/face
#   copying src/python/grpcio/grpc/framework/interfaces/face/utilities.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/interfaces/face
#   copying src/python/grpcio/grpc/framework/interfaces/face/face.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/interfaces/face
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/interfaces/base
#   copying src/python/grpcio/grpc/framework/interfaces/base/__init__.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/interfaces/base
#   copying src/python/grpcio/grpc/framework/interfaces/base/utilities.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/interfaces/base
#   copying src/python/grpcio/grpc/framework/interfaces/base/base.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/framework/interfaces/base
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc/_cython/_cygrpc
#   copying src/python/grpcio/grpc/_cython/_cygrpc/__init__.py -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/_cython/_cygrpc
#   creating python_build/lib.macosx-10.10-x86_64-3.8/grpc/_cython/_credentials
#   copying src/python/grpcio/grpc/_cython/_credentials/roots.pem -> python_build/lib.macosx-10.10-x86_64-3.8/grpc/_cython/_credentials
#   running build_ext
#   Found cython-generated files...
#   building 'grpc._cython.cygrpc' extension
#   creating python_build/temp.macosx-10.10-x86_64-3.8
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/python
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/python/grpcio
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/python/grpcio/grpc
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/python/grpcio/grpc/_cython
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/backend_metrics
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/census
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/channel_idle
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/health
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/lb_policy
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/lb_policy/grpclb
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/lb_policy/outlier_detection
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/lb_policy/pick_first
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/lb_policy/priority
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/lb_policy/ring_hash
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/lb_policy/rls
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/lb_policy/round_robin
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/lb_policy/weighted_round_robin
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/lb_policy/weighted_target
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/lb_policy/xds
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/resolver
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/resolver/binder
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/resolver/dns
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/resolver/dns/c_ares
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/resolver/dns/native
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/resolver/fake
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/resolver/google_c2p
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/resolver/sockaddr
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/client_channel/resolver/xds
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/deadline
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/fault_injection
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/http
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/http/client
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/http/message_compress
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/http/server
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/message_size
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/rbac
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/server_config_selector
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/filters/stateful_session
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/transport
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/transport/chttp2
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/transport/chttp2/alpn
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/transport/chttp2/client
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/transport/chttp2/server
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/transport/chttp2/transport
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/transport/inproc
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/admin
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/admin/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/annotations
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/accesslog
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/accesslog/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/bootstrap
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/bootstrap/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/cluster
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/cluster/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/common
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/common/matcher
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/common/matcher/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/core
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/core/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/endpoint
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/endpoint/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/listener
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/listener/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/metrics
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/metrics/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/overload
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/overload/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/rbac
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/rbac/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/route
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/route/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/tap
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/tap/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/trace
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/config/trace/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/clusters
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/clusters/aggregate
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/clusters/aggregate/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/common
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/common/fault
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/common/fault/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/http
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/http/fault
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/http/fault/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/http/rbac
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/http/rbac/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/http/router
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/http/router/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/http/stateful_session
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/http/stateful_session/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/network
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/network/http_connection_manager
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/filters/network/http_connection_manager/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/http
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/http/stateful_session
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/http/stateful_session/cookie
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/http/stateful_session/cookie/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies/client_side_weighted_round_robin
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies/client_side_weighted_round_robin/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies/common
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies/common/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies/ring_hash
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies/ring_hash/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies/wrr_locality
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/load_balancing_policies/wrr_locality/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/transport_sockets
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/transport_sockets/tls
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/extensions/transport_sockets/tls/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/service
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/service/discovery
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/service/discovery/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/service/load_stats
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/service/load_stats/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/service/status
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/service/status/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/type
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/type/http
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/type/http/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/type/matcher
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/type/matcher/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/type/metadata
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/type/metadata/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/type/tracing
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/type/tracing/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/envoy/type/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/google
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/google/api
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/google/api/expr
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/google/api/expr/v1alpha1
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/google/protobuf
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/google/rpc
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/opencensus
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/opencensus/proto
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/opencensus/proto/trace
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/opencensus/proto/trace/v1
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/src
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/src/proto
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/src/proto/grpc
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/src/proto/grpc/gcp
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/src/proto/grpc/health
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/src/proto/grpc/health/v1
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/src/proto/grpc/lb
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/src/proto/grpc/lb/v1
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/src/proto/grpc/lookup
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/src/proto/grpc/lookup/v1
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/udpa
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/udpa/annotations
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/validate
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/annotations
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/annotations/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/core
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/core/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/data
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/data/orca
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/data/orca/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/service
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/service/orca
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/service/orca/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/type
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/type/matcher
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/type/matcher/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upb-generated/xds/type/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/admin
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/admin/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/annotations
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/accesslog
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/accesslog/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/bootstrap
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/bootstrap/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/cluster
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/cluster/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/common
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/common/matcher
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/common/matcher/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/core
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/core/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/endpoint
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/endpoint/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/listener
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/listener/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/metrics
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/metrics/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/overload
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/overload/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/rbac
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/rbac/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/route
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/route/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/tap
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/tap/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/trace
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/config/trace/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/clusters
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/clusters/aggregate
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/clusters/aggregate/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/common
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/common/fault
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/common/fault/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/http
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/fault
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/fault/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/rbac
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/rbac/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/router
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/router/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/stateful_session
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/http/stateful_session/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/network
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/network/http_connection_manager
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/filters/network/http_connection_manager/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/http
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/http/stateful_session
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/http/stateful_session/cookie
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/http/stateful_session/cookie/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/transport_sockets
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/transport_sockets/tls
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/extensions/transport_sockets/tls/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/service
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/service/discovery
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/service/discovery/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/service/load_stats
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/service/load_stats/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/service/status
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/service/status/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/type
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/type/http
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/type/http/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/type/matcher
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/type/matcher/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/type/metadata
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/type/metadata/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/type/tracing
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/type/tracing/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/envoy/type/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/google
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/google/api
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/google/api/expr
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/google/api/expr/v1alpha1
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/google/protobuf
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/google/rpc
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/opencensus
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/opencensus/proto
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/opencensus/proto/trace
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/opencensus/proto/trace/v1
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/src
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/src/proto
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/src/proto/grpc
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/src/proto/grpc/lookup
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/src/proto/grpc/lookup/v1
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/udpa
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/udpa/annotations
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/validate
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/xds
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/xds/annotations
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/xds/annotations/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/xds/core
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/xds/core/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/xds/type
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/xds/type/matcher
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/xds/type/matcher/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/upbdefs-generated/xds/type/v3
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/ext/xds
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/address_utils
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/backoff
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/channel
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/compression
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/config
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/debug
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/event_engine
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/event_engine/posix_engine
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/event_engine/windows
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/experiments
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/gpr
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/gprpp
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/handshaker
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/http
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/iomgr
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/iomgr/event_engine_shims
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/json
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/load_balancing
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/matchers
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/promise
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/resolver
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/resource_quota
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/authorization
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/certificate_provider
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/context
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/alts
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/composite
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/external
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/fake
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/google_default
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/iam
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/insecure
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/jwt
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/local
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/oauth2
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/plugin
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/ssl
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/tls
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/credentials/xds
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/security_connector
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/security_connector/alts
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/security_connector/fake
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/security_connector/insecure
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/security_connector/local
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/security_connector/ssl
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/security_connector/tls
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/transport
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/security/util
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/service_config
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/slice
#   creating python_build/temp.macosx-10.10-x86_64-3.8/src/core/lib/surface
# ...
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/alyssajames/opt/anaconda3/include -arch x86_64 -I/Users/alyssajames/opt/anaconda3/include -arch x86_64 -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX="Python" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX="1.53.0" -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 -DPyMODINIT_FUNC=extern "C" __attribute__((visibility ("default"))) PyObject* -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Users/alyssajames/opt/anaconda3/include/python3.8 -c third_party/re2/re2/filtered_re2.cc -o python_build/temp.macosx-10.10-x86_64-3.8/third_party/re2/re2/filtered_re2.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/alyssajames/opt/anaconda3/include -arch x86_64 -I/Users/alyssajames/opt/anaconda3/include -arch x86_64 -D_WIN32_WINNT=1536 -DGRPC_XDS_USER_AGENT_NAME_SUFFIX="Python" -DGRPC_XDS_USER_AGENT_VERSION_SUFFIX="1.53.0" -DGPR_BACKWARDS_COMPATIBILITY_MODE=1 -DHAVE_CONFIG_H=1 -DGRPC_ENABLE_FORK_SUPPORT=1 -DPyMODINIT_FUNC=extern "C" __attribute__((visibility ("default"))) PyObject* -DGRPC_POSIX_FORK_ALLOW_PTHREAD_ATFORK=1 -Isrc/python/grpcio -Iinclude -I. -Ithird_party/abseil-cpp -Ithird_party/address_sorting/include -Ithird_party/cares/cares/include -Ithird_party/cares -Ithird_party/cares/cares -Ithird_party/cares/config_darwin -Ithird_party/re2 -Ithird_party/boringssl-with-bazel/src/include -Ithird_party/upb -Isrc/core/ext/upb-generated -Isrc/core/ext/upbdefs-generated -Ithird_party/xxhash -Ithird_party/zlib -I/Users/alyssajames/opt/anaconda3/include/python3.8 -c third_party/zlib/compress.c -o python_build/temp.macosx-10.10-x86_64-3.8/third_party/zlib/compress.o -std=c++14 -stdlib=libc++ -fvisibility=hidden -fno-wrapv -fno-exceptions -DHAVE_UNISTD_H -pthread
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#   creating None
#   creating None/var
#   creating None/var/folders
#   creating None/var/folders/lx
#   creating None/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp
#   creating None/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T
#   creating None/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/tmpb5otgqmr
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/alyssajames/opt/anaconda3/include -arch x86_64 -I/Users/alyssajames/opt/anaconda3/include -arch x86_64 -I/Users/alyssajames/opt/anaconda3/include/python3.8 -c /var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/tmpb5otgqmr/a.c -o None/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/tmpb5otgqmr/a.o
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#
#   Could not find <Python.h>. This could mean the following:
#     * You're on Ubuntu and haven't run `apt-get install python3-dev`.
#     * You're on RHEL/Fedora and haven't run `yum install python3-devel` or
#       `dnf install python3-devel` (make sure you also have redhat-rpm-config
#       installed)
#     * You're on Mac OS X and the usual Python framework was somehow corrupted
#       (check your environment variables or try re-installing?)
#     * You're on Windows and your Python installation was somehow corrupted
#       (check your environment variables or try re-installing?)
#   Traceback (most recent call last):
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/unixccompiler.py", line 117, in _compile
#       self.spawn(compiler_so + cc_args + [src, '-o', obj] +
#     File "/private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-install-olv8jqwe/grpcio/src/python/grpcio/_spawn_patch.py", line 54, in _commandfile_spawn
#       _classic_spawn(self, command)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/ccompiler.py", line 910, in spawn
#       spawn(cmd, dry_run=self.dry_run)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/spawn.py", line 36, in spawn
#       _spawn_posix(cmd, search_path, dry_run=dry_run)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/spawn.py", line 157, in _spawn_posix
#       raise DistutilsExecError(
#   distutils.errors.DistutilsExecError: command 'gcc' failed with exit status 1
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "/private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-install-olv8jqwe/grpcio/src/python/grpcio/commands.py", line 281, in build_extensions
#       build_ext.build_ext.build_extensions(self)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages/Cython/Distutils/old_build_ext.py", line 195, in build_extensions
#       _build_ext.build_ext.build_extensions(self)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/command/build_ext.py", line 449, in build_extensions
#       self._build_extensions_serial()
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/command/build_ext.py", line 474, in _build_extensions_serial
#       self.build_extension(ext)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages/setuptools/command/build_ext.py", line 196, in build_extension
#       _build_ext.build_extension(self, ext)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/command/build_ext.py", line 528, in build_extension
#       objects = self.compiler.compile(sources,
#     File "/private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-install-olv8jqwe/grpcio/src/python/grpcio/_parallel_compile_patch.py", line 58, in _parallel_compile
#       multiprocessing.pool.ThreadPool(BUILD_EXT_COMPILER_JOBS).map(
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 364, in map
#       return self._map_async(func, iterable, mapstar, chunksize).get()
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 771, in get
#       raise self._value
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 125, in worker
#       result = (True, func(*args, **kwds))
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/multiprocessing/pool.py", line 48, in mapstar
#       return list(map(*args))
#     File "/private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-install-olv8jqwe/grpcio/src/python/grpcio/_parallel_compile_patch.py", line 54, in _compile_single_file
#       self._compile(obj, src, ext, cc_args, extra_postargs, pp_opts)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/unixccompiler.py", line 120, in _compile
#       raise CompileError(msg)
#   distutils.errors.CompileError: command 'gcc' failed with exit status 1
#
#   During handling of the above exception, another exception occurred:
#
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-install-olv8jqwe/grpcio/setup.py", line 535, in <module>
#       setuptools.setup(
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages/wheel/bdist_wheel.py", line 290, in run
#       self.run_command('build')
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/command/build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages/setuptools/command/build_ext.py", line 79, in run
#       _build_ext.run(self)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages/Cython/Distutils/old_build_ext.py", line 186, in run
#       _build_ext.build_ext.run(self)
#     File "/Users/alyssajames/opt/anaconda3/lib/python3.8/distutils/command/build_ext.py", line 340, in run
#       self.build_extensions()
#     File "/private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-install-olv8jqwe/grpcio/src/python/grpcio/commands.py", line 284, in build_extensions
#       support.diagnose_build_ext_error(self, error, formatted_exception)
#     File "/private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-install-olv8jqwe/grpcio/src/python/grpcio/support.py", line 117, in diagnose_build_ext_error
#       diagnostic(build_ext, error)
#     File "/private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-install-olv8jqwe/grpcio/src/python/grpcio/support.py", line 76, in diagnose_compile_error
#       _expect_compile(build_ext.compiler, c_check, message)
#     File "/private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-install-olv8jqwe/grpcio/src/python/grpcio/support.py", line 68, in _expect_compile
#       raise commands.CommandError(
#   commands.CommandError: Diagnostics found a compilation environment issue:
#
#   Could not find <Python.h>. This could mean the following:
#     * You're on Ubuntu and haven't run `apt-get install python3-dev`.
#     * You're on RHEL/Fedora and haven't run `yum install python3-devel` or
#       `dnf install python3-devel` (make sure you also have redhat-rpm-config
#       installed)
#     * You're on Mac OS X and the usual Python framework was somehow corrupted
#       (check your environment variables or try re-installing?)
#     * You're on Windows and your Python installation was somehow corrupted
#       (check your environment variables or try re-installing?)
#
#   ----------------------------------------
#   ERROR: Failed building wheel for grpcio
#   Running setup.py clean for grpcio
#   Building wheel for ml-dtypes (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/alyssajames/opt/anaconda3/bin/python /Users/alyssajames/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/tmpv9w9pu_f
#        cwd: /private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-install-olv8jqwe/ml-dtypes
#   Complete output (23 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-cpython-38
#   creating build/lib.macosx-10.9-x86_64-cpython-38/ml_dtypes
#   copying ml_dtypes/__init__.py -> build/lib.macosx-10.9-x86_64-cpython-38/ml_dtypes
#   copying ml_dtypes/_finfo.py -> build/lib.macosx-10.9-x86_64-cpython-38/ml_dtypes
#   creating build/lib.macosx-10.9-x86_64-cpython-38/ml_dtypes/tests
#   copying ml_dtypes/tests/custom_float_test.py -> build/lib.macosx-10.9-x86_64-cpython-38/ml_dtypes/tests
#   copying ml_dtypes/tests/finfo_test.py -> build/lib.macosx-10.9-x86_64-cpython-38/ml_dtypes/tests
#   copying ml_dtypes/tests/metadata_test.py -> build/lib.macosx-10.9-x86_64-cpython-38/ml_dtypes/tests
#   copying ml_dtypes/py.typed -> build/lib.macosx-10.9-x86_64-cpython-38/ml_dtypes
#   running build_ext
#   building 'ml_dtypes._custom_floats' extension
#   creating build/temp.macosx-10.9-x86_64-cpython-38
#   creating build/temp.macosx-10.9-x86_64-cpython-38/ml_dtypes
#   creating build/temp.macosx-10.9-x86_64-cpython-38/ml_dtypes/_src
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/alyssajames/opt/anaconda3/include -arch x86_64 -I/Users/alyssajames/opt/anaconda3/include -arch x86_64 -Ithird_party -Iml_dtypes -I/private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-build-env-k4o5sd3i/overlay/lib/python3.8/site-packages/numpy/core/include -I/private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-build-env-k4o5sd3i/overlay/lib/python3.8/site-packages/pybind11/include -I/Users/alyssajames/opt/anaconda3/include/python3.8 -c ml_dtypes/_src/dtypes.cc -o build/temp.macosx-10.9-x86_64-cpython-38/ml_dtypes/_src/dtypes.o -fvisibility=hidden -g0 -stdlib=libc++ -std=c++17 -DEIGEN_MPL2_ONLY
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#   /private/var/folders/lx/1fqb9z1x3x53xmjzc_rc95m00000gp/T/pip-build-env-k4o5sd3i/overlay/lib/python3.8/site-packages/setuptools/config/pyprojecttoml.py:108: _BetaConfiguration: Support for `[tool.setuptools]` in `pyproject.toml` is still *beta*.
#     warnings.warn(msg, _BetaConfiguration)
#   error: command '/usr/bin/gcc' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for ml-dtypes
# Failed to build grpcio ml-dtypes
# ERROR: Could not build wheels for ml-dtypes which use PEP 517 and cannot be installed directly
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Load data from CSV file
data = pd.read_csv("/Users/alyssajames/BMEN415/Regression Models/cancer_reg_updated.csv")

# Fill missing values with the mean of the respective column
data = data.fillna(data.mean())

# Separate features and target variable
X = data.drop(['avgDeathsPerYear'], axis=1)
y = data['avgDeathsPerYear']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features for better training performance
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Create the neural network model
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='linear'))

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam')

# Fit the model to the training data
model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1)

# Predict the target values for the test data
y_pred = model.predict(X_test).flatten()

# Print the mean squared error, root mean squared error, mean absolute error, and R2 score of the model
print("Mean squared error:", mean_squared_error(y_test, y_pred))
print("Root mean squared error:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("Mean absolute error:", mean_absolute_error(y_test, y_pred))
print("R2 score:", r2_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-94c9761905c6> in <module>
#       5 from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
#       6 from sklearn.preprocessing import StandardScaler
# ----> 7 from tensorflow.keras.models import Sequential
#       8 from tensorflow.keras.layers import Dense
#       9
#
# ModuleNotFoundError: No module named 'tensorflow'
